# %%
import numpy as np
import pandas as pd


col_names = ['iteration', 'ouroboros_count', 'bite_count', 'head_to_head_count', 'seed', 
             'score_a', 'score_b', 'score_c', 'score_d']
df = pd.read_csv('./results.txt', header=0, names=col_names, delimiter="\t")

df.nlargest(10, 'bite_count')
# df.head(10)
# Out:
#         iteration  ouroboros_count  bite_count  head_to_head_count  \
# 102233        700                7          41                 235
# 863771        649                5          39                   3
# 270486        606                6          37                  12
# 91829         651                7          36                   5
# 890787        620                5          36                  10
# 205676        573                4          35                  12
# 262364        604                7          35                  16
# 539393        627                6          35                   9
# 548341        551                5          35                  36
# 573896        637                7          35                   4
#
#                         seed  score_a  score_b  score_c  score_d
# 102233  12768477609909882769      151       38      970      259
# 863771   2216562425439805338        1      128      282      990
# ...
